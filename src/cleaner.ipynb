# %%
import os
import json
ROOT_DIR = os.getcwd()
document_type = "bank_statements"
template_name = "halifax"
identifier = "march"

pdf_path: str = os.path.join(
    ROOT_DIR,
    "data",
    document_type,
    template_name,
    "pdf",
    f"{template_name}_{identifier}.pdf",
)

# %%
output_path: str = os.path.join(
    ROOT_DIR,
    "outputs",
    f"{template_name}_{identifier}_output.json",
)


output = json.load(open(output_path))

# %%
from cleaner import DocumentCleaner

if __name__ == "__main__":
    path = os.path.join(ROOT_DIR, "cleaner_config", "halifax_cleaner_config.json")
    cleaner = DocumentCleaner(path)

    for page in output["pages"]:
        cleaned_page = cleaner.clean_page(page)

# %%
page
# Out:
# {'forms': [{'customer_name': 'Mr Jake Holmes'},
#   {'sort_code': '11-00-56'},
#   {'account_number': '11980162'},
#   {'money_in': '£611.98'},
#   {'start_balance': '£410.22'},
#   {'money_out': '£523.87'},
#   {'end_balance': '£521.23'}],
#  'tables': [{'data': [{'date': '01 Mar 23',
#      'type': 'DD',
#      'description': 'UNIVERSITY OF NOTT',
#      'money_out': '22.90',
#      'money_in': '',
#      'balance': '410.22'},
#     {'date': '01 Mar 23',
#      'type': 'TFR',
#      'description': 'FORGN PYT266644037',
#      'money_out': '87.27',
#      'money_in': '',
#      'balance': '322.95'},
#     {'date': '01 Mar 23',
#      'type': 'DEB',
#      'description': 'GOOGLE Domains',
#      'money_out': '8.28',
#      'money_in': '',
#      'balance': '314.67'},
#     {'date': '02 Mar 23',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': '48.00',
#      'balance': '362.67'},
#     {'date': '02 Mar 23',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': '152.80',
#      'balance': '515.47'},
#     {'date': '09 Mar 23',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': '81.59',
#      'balance': '597.06'},
#     {'date': '09 Mar 23',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': '46.40',
#      'balance': '643.46'},
#     {'date': '10 Mar 23',
#      'type': 'DEB',
#      'description': 'HEROKU FEB-7910926',
#      'money_out': '21.99',
#      'money_in': '',
#      'balance': '621.47'},
#     {'date': '10 Mar 23',
#      'type': 'DEB',
#      'description': 'NON-GBP TRANS FEE',
#      'money_out': '0.65',
#      'money_in': '',
#      'balance': '620.82'},
#     {'date': '10 Mar 23',
#      'type': 'DEB',
#      'description': 'NON-GBP PURCH FEE',
#      'money_out': '0.50',
#      'money_in': '',
#      'balance': '620.32'},
#     {'date': '13 Mar 23',
#      'type': 'DEB',
#      'description': 'GOOGLE Domains',
#      'money_out': '4.14',
#      'money_in': '',
#      'balance': '616.18'},
#     {'date': '14 Mar 23',
#      'type': 'DEB',
#      'description': 'GOOGLE Domains',
#      'money_out': '4.60',
#      'money_in': '',
#      'balance': '611.58'},
#     {'date': '16 Mar 23',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': '68.80',
#      'balance': '680.38'},
#     {'date': '16 Mar 23',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': '25.60',
#      'balance': '705.98'},
#     {'date': '20 Mar 23',
#      'type': 'DEB',
#      'description': 'GOOGLE Domains',
#      'money_out': '16.56',
#      'money_in': '',
#      'balance': '689.42'},
#     {'date': '21 Mar 23',
#      'type': 'FPO',
#      'description': 'TESCO BANK',
#      'money_out': '68.70',
#      'money_in': '',
#      'balance': '620.72'},
#     {'date': '',
#      'type': '',
#      'description': '',
#      'money_out': '',
#      'money_in': '',
#      'balance': ''}]},
#   {'data': [{'date': '23 Mar 23',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': '69.59',
#      'balance': '690.31'},
#     {'date': '23 Mar 23',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': '48.00',
#      'balance': '738.31'},
#     {'date': '23 Mar 23',
#      'type': 'FPO',
#      'description': 'RAJ',
#      'money_out': '200.00',
#      'money_in': '',
#      'balance': '538.31'},
#     {'date': '29 Mar 23',
#      'type': 'DEB',
#      'description': 'GOOGLE Domains',
#      'money_out': '8.28',
#      'money_in': '',
#      'balance': '530.03'},
#     {'date': '29 Mar 23',
#      'type': 'FPO',
#      'description': 'SAMMY MALOUMI',
#      'money_out': '70.00',
#      'money_in': '',
#      'balance': '460.03'},
#     {'date': '30 Mar 23',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': '23.20',
#      'balance': '483.23'},
#     {'date': '30 Mar 23',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': '48.00',
#      'balance': '531.23'},
#     {'date': '31 Mar 23',
#      'type': 'DEB',
#      'description': 'GOOGLE Domains',
#      'money_out': '10.00',
#      'money_in': '',
#      'balance': '521.23'},
#     {'date': '',
#      'type': '',
#      'description': '',
#      'money_out': '',
#      'money_in': '',
#      'balance': ''}]}]}

# %%
cleaned_page
# Out:
# {'forms': [{'customer_name': 'Mr Jake Holmes'},
#   {'sort_code': '11-00-56'},
#   {'account_number': '11980162'},
#   {'money_in': 61198},
#   {'start_balance': 41022},
#   {'money_out': 52387},
#   {'end_balance': 52123}],
#  'tables': [{'data': [{'date': '2023-03-01',
#      'type': 'DD',
#      'description': 'UNIVERSITY OF NOTT',
#      'money_out': 2290,
#      'money_in': '',
#      'balance': 41022},
#     {'date': '2023-03-01',
#      'type': 'TFR',
#      'description': 'FORGN PYT266644037',
#      'money_out': 8727,
#      'money_in': '',
#      'balance': 32295},
#     {'date': '2023-03-01',
#      'type': 'DEB',
#      'description': 'GOOGLE Domains',
#      'money_out': 828,
#      'money_in': '',
#      'balance': 31467},
#     {'date': '2023-03-02',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': 4800,
#      'balance': 36267},
#     {'date': '2023-03-02',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': 15280,
#      'balance': 51547},
#     {'date': '2023-03-09',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': 8159,
#      'balance': 59706},
#     {'date': '2023-03-09',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': 4640,
#      'balance': 64346},
#     {'date': '2023-03-10',
#      'type': 'DEB',
#      'description': 'HEROKU FEB-7910926',
#      'money_out': 2199,
#      'money_in': '',
#      'balance': 62147},
#     {'date': '2023-03-10',
#      'type': 'DEB',
#      'description': 'NON-GBP TRANS FEE',
#      'money_out': 65,
#      'money_in': '',
#      'balance': 62082},
#     {'date': '2023-03-10',
#      'type': 'DEB',
#      'description': 'NON-GBP PURCH FEE',
#      'money_out': 50,
#      'money_in': '',
#      'balance': 62032},
#     {'date': '2023-03-13',
#      'type': 'DEB',
#      'description': 'GOOGLE Domains',
#      'money_out': 414,
#      'money_in': '',
#      'balance': 61618},
#     {'date': '2023-03-14',
#      'type': 'DEB',
#      'description': 'GOOGLE Domains',
#      'money_out': 460,
#      'money_in': '',
#      'balance': 61158},
#     {'date': '2023-03-16',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': 6880,
#      'balance': 68038},
#     {'date': '2023-03-16',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': 2560,
#      'balance': 70598},
#     {'date': '2023-03-20',
#      'type': 'DEB',
#      'description': 'GOOGLE Domains',
#      'money_out': 1656,
#      'money_in': '',
#      'balance': 68942},
#     {'date': '2023-03-21',
#      'type': 'FPO',
#      'description': 'TESCO BANK',
#      'money_out': 6870,
#      'money_in': '',
#      'balance': 62072},
#     {'date': '',
#      'type': '',
#      'description': '',
#      'money_out': '',
#      'money_in': '',
#      'balance': ''}]},
#   {'data': [{'date': '2023-03-23',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': 6959,
#      'balance': 69031},
#     {'date': '2023-03-23',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': 4800,
#      'balance': 73831},
#     {'date': '2023-03-23',
#      'type': 'FPO',
#      'description': 'RAJ',
#      'money_out': 20000,
#      'money_in': '',
#      'balance': 53831},
#     {'date': '2023-03-29',
#      'type': 'DEB',
#      'description': 'GOOGLE Domains',
#      'money_out': 828,
#      'money_in': '',
#      'balance': 53003},
#     {'date': '2023-03-29',
#      'type': 'FPO',
#      'description': 'SAMMY MALOUMI',
#      'money_out': 7000,
#      'money_in': '',
#      'balance': 46003},
#     {'date': '2023-03-30',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': 2320,
#      'balance': 48323},
#     {'date': '2023-03-30',
#      'type': 'FPI',
#      'description': 'HIYACAR LTD',
#      'money_out': '',
#      'money_in': 4800,
#      'balance': 53123},
#     {'date': '2023-03-31',
#      'type': 'DEB',
#      'description': 'GOOGLE Domains',
#      'money_out': 1000,
#      'money_in': '',
#      'balance': 52123},
#     {'date': '',
#      'type': '',
#      'description': '',
#      'money_out': '',
#      'money_in': '',
#      'balance': ''}]}]}

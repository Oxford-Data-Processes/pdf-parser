# %%
import os
import json
ROOT_DIR = os.getcwd()
document_type = "bank_statements"
template_name = "monzo"
identifier = "november"

pdf_path: str = os.path.join(
    ROOT_DIR,
    "data",
    document_type,
    template_name,
    "pdf",
    f"{template_name}_{identifier}.pdf",
)

# %%
output_path: str = os.path.join(
    ROOT_DIR,
    "outputs",
    f"{template_name}_{identifier}_output.json",
)


output = json.load(open(output_path))

# %%
from cleaner import DocumentCleaner

if __name__ == "__main__":
    path = os.path.join(ROOT_DIR, "cleaner_config", f"{template_name}_cleaner_config.json")
    cleaner = DocumentCleaner(path)

    for page in output["pages"]:
        cleaned_page = cleaner.clean_page(page)

# %%
page
# Out:
# {'forms': [{'customer_name': 'Christopher Michael Little'},
#   {'sort_code': '04-00-04'},
#   {'account_number': '60397861'},
#   {'end_balance': '£1,030.16'},
#   {'total_outgoings': '-£1,786.58'},
#   {'total_deposits': '£1,908.85'}],
#  'tables': [{'data': [{'date': '30/11/2023',
#      'description': 'Trainline +443332022222 GBR',
#      'amount': '-2.60',
#      'balance': '1,030.16'},
#     {'date': '30/11/2023',
#      'description': 'C LITTLE (Faster Payments) Reference: MONZO CASH',
#      'amount': '950.00',
#      'balance': '1,032.76'},
#     {'date': '29/11/2023',
#      'description': 'Zettle_*OXPRO LIMITED Oxford GBR',
#      'amount': '-4.00',
#      'balance': '82.76'},
#     {'date': '29/11/2023',
#      'description': 'Trainline +443332022222 GBR',
#      'amount': '-2.60',
#      'balance': '86.76'},
#     {'date': '29/11/2023',
#      'description': 'DICE.FM +442080687457 GBR',
#      'amount': '-27.50',
#      'balance': '89.36'},
#     {'date': '28/11/2023',
#      'description': 'Trainline.com Ltd London GBR',
#      'amount': '-2.60',
#      'balance': '116.86'},
#     {'date': '28/11/2023',
#      'description': 'DAMIRA DENTAL STUDIO BICESTER OX26 GBR',
#      'amount': '-15.00',
#      'balance': '119.46'},
#     {'date': '27/11/2023',
#      'description': 'Amazon.co.uk AMAZON.CO.UK GBR',
#      'amount': '-15.99',
#      'balance': '134.46'},
#     {'date': '27/11/2023',
#      'description': 'ALDI STORES LIMITED BICESTER GBR',
#      'amount': '-34.97',
#      'balance': '150.45'},
#     {'date': '', 'description': '', 'amount': '', 'balance': ''},
#     {'date': '', 'description': '', 'amount': '', 'balance': ''}]},
#   {'data': [{'date': '', 'description': '', 'amount': '', 'balance': ''},
#     {'date': '26/11/2023',
#      'description': 'ATGTICKETS.COM WOKING GBR',
#      'amount': '-56.95',
#      'balance': '185.42'},
#     {'date': '26/11/2023',
#      'description': 'C Little (Faster Payments) Reference: MONZO CASH',
#      'amount': '200.00',
#      'balance': '242.37'},
#     {'date': '26/11/2023',
#      'description': 'TfL Travel Charge TFL.gov.uk/CP GBR',
#      'amount': '-8.10',
#      'balance': '42.37'},
#     {'date': '25/11/2023',
#      'description': 'M&S SIMPLY FOOD - SSP M/BONE STN GBR',
#      'amount': '-6.15',
#      'balance': '50.47'},
#     {'date': '25/11/2023',
#      'description': 'Builders Arms LONDON GBR',
#      'amount': '-20.45',
#      'balance': '56.62'},
#     {'date': '25/11/2023',
#      'description': 'Trainline +443332022222 GBR',
#      'amount': '-20.90',
#      'balance': '77.07'},
#     {'date': '23/11/2023',
#      'description': 'ALDI STORES LIMITED BICESTER GBR',
#      'amount': '-20.82',
#      'balance': '97.97'},
#     {'date': '23/11/2023',
#      'description': 'SAINSBURYS BICESTER GBR',
#      'amount': '-14.00',
#      'balance': '118.79'},
#     {'date': '20/11/2023',
#      'description': 'ALDI STORES LIMITED BICESTER GBR',
#      'amount': '-26.45',
#      'balance': '132.79'},
#     {'date': '19/11/2023',
#      'description': 'Prime Video TVOD 08444820123 GBR',
#      'amount': '-3.19',
#      'balance': '159.24'},
#     {'date': '19/11/2023',
#      'description': 'TFL TRAVEL CH\\VICTORIA STREET\\TFL.GOV.UK/CP\\SW1H 0TL GBR This relates to a previous transaction',
#      'amount': '-5.40',
#      'balance': '162.43'},
#     {'date': '19/11/2023',
#      'description': 'SAINSBURY S BANBURY BANBURY GBR This relates to a previous transaction',
#      'amount': '48.85',
#      'balance': '167.83'},
#     {'date': '19/11/2023',
#      'description': 'SAINSBURY S BANBURY BANBURY GBR',
#      'amount': '-100.00',
#      'balance': '118.98'},
#     {'date': '19/11/2023',
#      'description': 'SAINSBURYS- BANBURY BANBURY GBR',
#      'amount': '-30.45',
#      'balance': '218.98'},
#     {'date': '19/11/2023',
#      'description': 'Transfer from Pot',
#      'amount': '200.00',
#      'balance': '249.43'},
#     {'date': '19/11/2023',
#      'description': 'ALDI STORES LIMITED BICESTER GBR',
#      'amount': '-3.17',
#      'balance': '49.43'},
#     {'date': '19/11/2023',
#      'description': 'WESTGATE OXFORD CAR PA OXFORD GBR',
#      'amount': '-27.20',
#      'balance': '52.60'},
#     {'date': '18/11/2023',
#      'description': 'Prime Video TVOD 08444820123 GBR',
#      'amount': '-3.49',
#      'balance': '79.80'},
#     {'date': '18/11/2023',
#      'description': 'J. SAINSBURY OXFORD GBR',
#      'amount': '-18.65',
#      'balance': '83.29'},
#     {'date': '18/11/2023',
#      'description': 'UNIV OF OXFORD DONATIO OXFORD GBR',
#      'amount': '-5.00',
#      'balance': '101.94'},
#     {'date': '18/11/2023',
#      'description': 'ITSU 101 OXFORD OXFORD GBR',
#      'amount': '-16.48',
#      'balance': '106.94'},
#     {'date': '17/11/2023',
#      'description': 'Troxy London GBR',
#      'amount': '-10.00',
#      'balance': '123.42'},
#     {'date': '', 'description': '', 'amount': '', 'balance': ''},
#     {'date': '', 'description': '', 'amount': '', 'balance': ''}]},
#   {'data': [{'date': '', 'description': '', 'amount': '', 'balance': ''},
#     {'date': '17/11/2023',
#      'description': 'CO-OP GROUP FOOD LONDON GBR',
#      'amount': '-1.10',
#      'balance': '133.42'},
#     {'date': '17/11/2023',
#      'description': 'M&S SIMPLY FOOD - SSP M/BONE STN GBR',
#      'amount': '-8.15',
#      'balance': '134.52'},
#     {'date': '17/11/2023',
#      'description': 'Trainline.com Ltd London GBR',
#      'amount': '-20.90',
#      'balance': '142.67'},
#     {'date': '17/11/2023',
#      'description': 'Transfer from Pot',
#      'amount': '100.00',
#      'balance': '163.57'},
#     {'date': '14/11/2023',
#      'description': 'ALDI STORES LIMITED BICESTER GBR',
#      'amount': '-30.68',
#      'balance': '63.57'},
#     {'date': '14/11/2023',
#      'description': 'Amazon.co.uk AMAZON.CO.UK GBR',
#      'amount': '-7.99',
#      'balance': '94.25'},
#     {'date': '13/11/2023',
#      'description': 'Trainline.com Ltd London GBR',
#      'amount': '-2.60',
#      'balance': '102.24'},
#     {'date': '13/11/2023',
#      'description': 'TFL TRAVEL CH\\VICTORIA STREET\\TFL.GOV.UK/CP\\SW1H 0TL GBR This relates to a previous transaction',
#      'amount': '-5.30',
#      'balance': '104.84'},
#     {'date': '12/11/2023',
#      'description': 'OXFORD BUS COMPANY\\COWLEY HOUSE, WATLIN\\OXFORD\\OX4 6GA GBRGBR This relates to a previous transaction',
#      'amount': '-1.90',
#      'balance': '110.14'},
#     {'date': '12/11/2023',
#      'description': 'Transfer from Pot',
#      'amount': '100.00',
#      'balance': '112.04'},
#     {'date': '12/11/2023',
#      'description': 'CO-OP GROUP FOOD LONDON GBR',
#      'amount': '-4.90',
#      'balance': '12.04'},
#     {'date': '12/11/2023',
#      'description': 'TESCO STORES 2097 LONDON GBR',
#      'amount': '-1.10',
#      'balance': '16.94'},
#     {'date': '12/11/2023',
#      'description': 'Ennismore Internationa London GBR',
#      'amount': '-39.38',
#      'balance': '18.04'},
#     {'date': '12/11/2023',
#      'description': 'TfL Travel Charge TFL.gov.uk/CP GBR',
#      'amount': '-0.10',
#      'balance': '57.42'},
#     {'date': '12/11/2023',
#      'description': 'Trainline.com Ltd London GBR',
#      'amount': '-20.90',
#      'balance': '57.52'},
#     {'date': '11/11/2023',
#      'description': 'OXFORD BUS COMPANY OXFORD GBR',
#      'amount': '-0.10',
#      'balance': '78.42'},
#     {'date': '11/11/2023',
#      'description': 'The Tasty Kitchen 2 South Ockendo GBR',
#      'amount': '-14.00',
#      'balance': '78.52'},
#     {'date': '11/11/2023',
#      'description': 'Amazon Prime amzn.co.uk/pm GBR',
#      'amount': '-8.99',
#      'balance': '92.52'},
#     {'date': '11/11/2023',
#      'description': 'Transfer from Pot',
#      'amount': '100.00',
#      'balance': '101.51'},
#     {'date': '11/11/2023',
#      'description': 'Trainline.com Ltd London GBR',
#      'amount': '-2.60',
#      'balance': '1.51'},
#     {'date': '10/11/2023',
#      'description': 'Helosh Ltd Watford GBR',
#      'amount': '-14.50',
#      'balance': '4.11'},
#     {'date': '10/11/2023',
#      'description': 'ALDI STORES LIMITED BICESTER GBR',
#      'amount': '-29.42',
#      'balance': '18.61'},
#     {'date': '', 'description': '', 'amount': '', 'balance': ''},
#     {'date': '', 'description': '', 'amount': '', 'balance': ''}]}]}

# %%
cleaned_page
# Out:
# {'forms': [{'customer_name': 'Christopher Michael Little'},
#   {'sort_code': '04-00-04'},
#   {'account_number': '60397861'},
#   {'end_balance': '103016'},
#   {'total_outgoings': '-178658'},
#   {'total_deposits': '190885'}],
#  'tables': [{'data': [{'date': '2023-11-30',
#      'description': 'Trainline +443332022222 GBR',
#      'amount': '-260',
#      'balance': '103016'},
#     {'date': '2023-11-30',
#      'description': 'C LITTLE (Faster Payments) Reference: MONZO CASH',
#      'amount': '95000',
#      'balance': '103276'},
#     {'date': '2023-11-29',
#      'description': 'Zettle_*OXPRO LIMITED Oxford GBR',
#      'amount': '-400',
#      'balance': '8276'},
#     {'date': '2023-11-29',
#      'description': 'Trainline +443332022222 GBR',
#      'amount': '-260',
#      'balance': '8676'},
#     {'date': '2023-11-29',
#      'description': 'DICE.FM +442080687457 GBR',
#      'amount': '-2750',
#      'balance': '8936'},
#     {'date': '2023-11-28',
#      'description': 'Trainline.com Ltd London GBR',
#      'amount': '-260',
#      'balance': '11686'},
#     {'date': '2023-11-28',
#      'description': 'DAMIRA DENTAL STUDIO BICESTER OX26 GBR',
#      'amount': '-1500',
#      'balance': '11946'},
#     {'date': '2023-11-27',
#      'description': 'Amazon.co.uk AMAZON.CO.UK GBR',
#      'amount': '-1599',
#      'balance': '13446'},
#     {'date': '2023-11-27',
#      'description': 'ALDI STORES LIMITED BICESTER GBR',
#      'amount': '-3497',
#      'balance': '15045'},
#     {'date': '', 'description': '', 'amount': '', 'balance': ''},
#     {'date': '', 'description': '', 'amount': '', 'balance': ''}]},
#   {'data': [{'date': '', 'description': '', 'amount': '', 'balance': ''},
#     {'date': '2023-11-26',
#      'description': 'ATGTICKETS.COM WOKING GBR',
#      'amount': '-5695',
#      'balance': '18542'},
#     {'date': '2023-11-26',
#      'description': 'C Little (Faster Payments) Reference: MONZO CASH',
#      'amount': '20000',
#      'balance': '24237'},
#     {'date': '2023-11-26',
#      'description': 'TfL Travel Charge TFL.gov.uk/CP GBR',
#      'amount': '-810',
#      'balance': '4237'},
#     {'date': '2023-11-25',
#      'description': 'M&S SIMPLY FOOD - SSP M/BONE STN GBR',
#      'amount': '-615',
#      'balance': '5047'},
#     {'date': '2023-11-25',
#      'description': 'Builders Arms LONDON GBR',
#      'amount': '-2045',
#      'balance': '5662'},
#     {'date': '2023-11-25',
#      'description': 'Trainline +443332022222 GBR',
#      'amount': '-2090',
#      'balance': '7707'},
#     {'date': '2023-11-23',
#      'description': 'ALDI STORES LIMITED BICESTER GBR',
#      'amount': '-2082',
#      'balance': '9797'},
#     {'date': '2023-11-23',
#      'description': 'SAINSBURYS BICESTER GBR',
#      'amount': '-1400',
#      'balance': '11879'},
#     {'date': '2023-11-20',
#      'description': 'ALDI STORES LIMITED BICESTER GBR',
#      'amount': '-2645',
#      'balance': '13279'},
#     {'date': '2023-11-19',
#      'description': 'Prime Video TVOD 08444820123 GBR',
#      'amount': '-319',
#      'balance': '15924'},
#     {'date': '2023-11-19',
#      'description': 'TFL TRAVEL CH\\VICTORIA STREET\\TFL.GOV.UK/CP\\SW1H 0TL GBR This relates to a previous transaction',
#      'amount': '-540',
#      'balance': '16243'},
#     {'date': '2023-11-19',
#      'description': 'SAINSBURY S BANBURY BANBURY GBR This relates to a previous transaction',
#      'amount': '4885',
#      'balance': '16783'},
#     {'date': '2023-11-19',
#      'description': 'SAINSBURY S BANBURY BANBURY GBR',
#      'amount': '-10000',
#      'balance': '11898'},
#     {'date': '2023-11-19',
#      'description': 'SAINSBURYS- BANBURY BANBURY GBR',
#      'amount': '-3045',
#      'balance': '21898'},
#     {'date': '2023-11-19',
#      'description': 'Transfer from Pot',
#      'amount': '20000',
#      'balance': '24943'},
#     {'date': '2023-11-19',
#      'description': 'ALDI STORES LIMITED BICESTER GBR',
#      'amount': '-317',
#      'balance': '4943'},
#     {'date': '2023-11-19',
#      'description': 'WESTGATE OXFORD CAR PA OXFORD GBR',
#      'amount': '-2720',
#      'balance': '5260'},
#     {'date': '2023-11-18',
#      'description': 'Prime Video TVOD 08444820123 GBR',
#      'amount': '-349',
#      'balance': '7980'},
#     {'date': '2023-11-18',
#      'description': 'J. SAINSBURY OXFORD GBR',
#      'amount': '-1865',
#      'balance': '8329'},
#     {'date': '2023-11-18',
#      'description': 'UNIV OF OXFORD DONATIO OXFORD GBR',
#      'amount': '-500',
#      'balance': '10194'},
#     {'date': '2023-11-18',
#      'description': 'ITSU 101 OXFORD OXFORD GBR',
#      'amount': '-1648',
#      'balance': '10694'},
#     {'date': '2023-11-17',
#      'description': 'Troxy London GBR',
#      'amount': '-1000',
#      'balance': '12342'},
#     {'date': '', 'description': '', 'amount': '', 'balance': ''},
#     {'date': '', 'description': '', 'amount': '', 'balance': ''}]},
#   {'data': [{'date': '', 'description': '', 'amount': '', 'balance': ''},
#     {'date': '2023-11-17',
#      'description': 'CO-OP GROUP FOOD LONDON GBR',
#      'amount': '-110',
#      'balance': '13342'},
#     {'date': '2023-11-17',
#      'description': 'M&S SIMPLY FOOD - SSP M/BONE STN GBR',
#      'amount': '-815',
#      'balance': '13452'},
#     {'date': '2023-11-17',
#      'description': 'Trainline.com Ltd London GBR',
#      'amount': '-2090',
#      'balance': '14267'},
#     {'date': '2023-11-17',
#      'description': 'Transfer from Pot',
#      'amount': '10000',
#      'balance': '16357'},
#     {'date': '2023-11-14',
#      'description': 'ALDI STORES LIMITED BICESTER GBR',
#      'amount': '-3068',
#      'balance': '6357'},
#     {'date': '2023-11-14',
#      'description': 'Amazon.co.uk AMAZON.CO.UK GBR',
#      'amount': '-799',
#      'balance': '9425'},
#     {'date': '2023-11-13',
#      'description': 'Trainline.com Ltd London GBR',
#      'amount': '-260',
#      'balance': '10224'},
#     {'date': '2023-11-13',
#      'description': 'TFL TRAVEL CH\\VICTORIA STREET\\TFL.GOV.UK/CP\\SW1H 0TL GBR This relates to a previous transaction',
#      'amount': '-530',
#      'balance': '10484'},
#     {'date': '2023-11-12',
#      'description': 'OXFORD BUS COMPANY\\COWLEY HOUSE, WATLIN\\OXFORD\\OX4 6GA GBRGBR This relates to a previous transaction',
#      'amount': '-190',
#      'balance': '11014'},
#     {'date': '2023-11-12',
#      'description': 'Transfer from Pot',
#      'amount': '10000',
#      'balance': '11204'},
#     {'date': '2023-11-12',
#      'description': 'CO-OP GROUP FOOD LONDON GBR',
#      'amount': '-490',
#      'balance': '1204'},
#     {'date': '2023-11-12',
#      'description': 'TESCO STORES 2097 LONDON GBR',
#      'amount': '-110',
#      'balance': '1694'},
#     {'date': '2023-11-12',
#      'description': 'Ennismore Internationa London GBR',
#      'amount': '-3938',
#      'balance': '1804'},
#     {'date': '2023-11-12',
#      'description': 'TfL Travel Charge TFL.gov.uk/CP GBR',
#      'amount': '-10',
#      'balance': '5742'},
#     {'date': '2023-11-12',
#      'description': 'Trainline.com Ltd London GBR',
#      'amount': '-2090',
#      'balance': '5752'},
#     {'date': '2023-11-11',
#      'description': 'OXFORD BUS COMPANY OXFORD GBR',
#      'amount': '-10',
#      'balance': '7842'},
#     {'date': '2023-11-11',
#      'description': 'The Tasty Kitchen 2 South Ockendo GBR',
#      'amount': '-1400',
#      'balance': '7852'},
#     {'date': '2023-11-11',
#      'description': 'Amazon Prime amzn.co.uk/pm GBR',
#      'amount': '-899',
#      'balance': '9252'},
#     {'date': '2023-11-11',
#      'description': 'Transfer from Pot',
#      'amount': '10000',
#      'balance': '10151'},
#     {'date': '2023-11-11',
#      'description': 'Trainline.com Ltd London GBR',
#      'amount': '-260',
#      'balance': '151'},
#     {'date': '2023-11-10',
#      'description': 'Helosh Ltd Watford GBR',
#      'amount': '-1450',
#      'balance': '411'},
#     {'date': '2023-11-10',
#      'description': 'ALDI STORES LIMITED BICESTER GBR',
#      'amount': '-2942',
#      'balance': '1861'},
#     {'date': '', 'description': '', 'amount': '', 'balance': ''},
#     {'date': '', 'description': '', 'amount': '', 'balance': ''}]}]}

# %%
import os
import json
ROOT_DIR = os.getcwd()
document_type = "bank_statements"
template_name = "barclays"
identifier = "march"

pdf_path: str = os.path.join(
    ROOT_DIR,
    "data",
    document_type,
    template_name,
    "pdf",
    f"{template_name}_{identifier}.pdf",
)

# %%
output_path: str = os.path.join(
    ROOT_DIR,
    "outputs",
    f"{template_name}_{identifier}_output.json",
)


output = json.load(open(output_path))

# %%
from cleaner import DocumentCleaner

if __name__ == "__main__":
    path = os.path.join(ROOT_DIR, "cleaner_config", f"{template_name}_cleaner_config.json")
    cleaner = DocumentCleaner(path)

    for page in output["pages"]:
        cleaned_page = cleaner.clean_page(page)

# %%
page
# Out:
# {'forms': [{'sort_code': '20-44-51'},
#   {'account_number': '83254534'},
#   {'customer_name': 'Miss Meghan Victoria Thorneloe'},
#   {'money_in': '667.92'},
#   {'start_balance': '36.30'},
#   {'money_out': '659.98'},
#   {'end_balance': '44.24'}],
#  'tables': [{'data': [{'date': '01 Mar',
#      'description': 'Start balance',
#      'money_out': '',
#      'money_in': '',
#      'balance': '36.30'},
#     {'date': '01 Mar',
#      'description': 'Transfer to Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '24.00',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Bill Payment From Thorneloe E J Ref: Food',
#      'money_out': '',
#      'money_in': '24.00',
#      'balance': '36.30'},
#     {'date': '02 Mar',
#      'description': 'Card Payment to Protein Works On 01 Mar',
#      'money_out': '3.96',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer to Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '23.00',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Received From S Oakley Ref: Water 2',
#      'money_out': '',
#      'money_in': '23.33',
#      'balance': '32.67'},
#     {'date': '06 Mar',
#      'description': 'Card Payment to Headingley Taps On 04 Mar',
#      'money_out': '0.60',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Original Oak On 04 Mar',
#      'money_out': '1.20',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Poco On 04 Mar',
#      'money_out': '2.50',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Tesco Stores 5628 On 05 Mar',
#      'money_out': '3.35',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Poco On 04 Mar',
#      'money_out': '8.00',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to LA Cafetiere On 04 Mar',
#      'money_out': '10.00',
#      'money_in': '',
#      'balance': ''},
#     {'date': 'Barclays and the Registered',
#      'description': 'UK PLC. Authorised by the Prudential Regulation Regulation Authority (Financial Services in England. Registered No. 9740322. Registered Office:',
#      'money_out': 'and No. 759676). 1 Churchill Place,',
#      'money_in': 'by the London E14 5HP.',
#      'balance': 'Continued Conduct'}]},
#   {'data': [{'date': '06 Mar',
#      'description': 'Transfer to Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '23.00',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Bill Payment to Jake Holmes Ref: Travel',
#      'money_out': '100.00',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Received From Copse S J Ref: Water',
#      'money_out': '',
#      'money_in': '23.33',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': '60.00',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': '100.00',
#      'balance': '67.35'},
#     {'date': '07 Mar',
#      'description': 'Card Payment to Ltt Vending Limite On 06 Mar',
#      'money_out': '1.50',
#      'money_in': '',
#      'balance': '65.85'},
#     {'date': '08 Mar',
#      'description': 'Card Payment to Avo On 07 Mar',
#      'money_out': '6.50',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Bill Payment to E J Thorneloe Ref: Food',
#      'money_out': '16.00',
#      'money_in': '',
#      'balance': '43.35'},
#     {'date': '09 Mar',
#      'description': 'Card Payment to Superpedestrian On 08 Mar',
#      'money_out': '1.70',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Superpedestrian On 08 Mar',
#      'money_out': '3.10',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to 200 Degrees On 08 Mar',
#      'money_out': '6.95',
#      'money_in': '',
#      'balance': '31.60'},
#     {'date': '10 Mar',
#      'description': 'Bill Payment to E J Thorneloe Ref: Mothers Day',
#      'money_out': '24.00',
#      'money_in': '',
#      'balance': '7.60'},
#     {'date': '13 Mar',
#      'description': 'Card Payment to London Theatre Dir On 12 Mar',
#      'money_out': '53.00',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer to Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '23.00',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer to Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '23.00',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Received From Price M J Ref: Water',
#      'money_out': '',
#      'money_in': '23.33',
#      'balance': ''},
#     {'date': '',
#      'description': 'Received From Lamees Ali Ref: Lamees',
#      'money_out': '',
#      'money_in': '23.33',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': '52.00',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': '53.00',
#      'balance': '60.26'},
#     {'date': '14 Mar',
#      'description': 'Bill Payment to E J Thorneloe Ref: Food',
#      'money_out': '2.85',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Bill Payment to E J Thorneloe Ref: Food',
#      'money_out': '7.00',
#      'money_in': '',
#      'balance': '50.41'},
#     {'date': '15 Mar',
#      'description': 'Direct Debit to Paypal Payment Ref: 5YV22229Xjkke',
#      'money_out': '7.94',
#      'money_in': '',
#      'balance': ''},
#     {'date': 'Page',
#      'description': 'Barclays Bank UK PLC. Authorised by 2 Regulation Authority (Financial Registered in England. Registered',
#      'money_out': 'the Prudential Register No. 9740322.',
#      'money_in': 'Authority Office: 1',
#      'balance': 'Continued and regulated by Place, London'}]},
#   {'data': [{'date': '15 Mar',
#      'description': 'Direct Debit to Paypal Payment Ref: 5YV22229Xjkke',
#      'money_out': '44.46',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': '10.00',
#      'balance': '8.01'},
#     {'date': '20 Mar',
#      'description': 'Card Payment to Avo On 19 Mar',
#      'money_out': '2.80',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': '60.00',
#      'balance': '65.21'},
#     {'date': '21 Mar',
#      'description': 'Card Payment to Paypal *BO and Tee On 19 Mar',
#      'money_out': '25.00',
#      'money_in': '',
#      'balance': '40.21'},
#     {'date': '22 Mar',
#      'description': 'Card Payment to Treatwell On 21 Mar',
#      'money_out': '15.00',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Puregym Limited On 21 Mar',
#      'money_out': '16.99',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Lounge Underwear On 21 Mar',
#      'money_out': '58.50',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Portland Coffee Co On 21 Mar',
#      'money_out': '2.30',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Bill Payment to E J Thorneloe Ref: Food',
#      'money_out': '2.50',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': '20.00',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': '20.00',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': '50.00',
#      'balance': '34.92'},
#     {'date': '23 Mar',
#      'description': 'Card Payment to Trainline.Com On 21 Mar',
#      'money_out': '13.99',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': '60.00',
#      'balance': '80.93'},
#     {'date': '24 Mar',
#      'description': 'Card Payment to SP Aybl On 23 Mar',
#      'money_out': '66.24',
#      'money_in': '',
#      'balance': '14.69'},
#     {'date': '27 Mar',
#      'description': 'Card Payment to Tesco Stores 5628 On 24 Mar',
#      'money_out': '1.25',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Sainsburys S/Mkts On 24 Mar',
#      'money_out': '2.00',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Tier Lounge Nottin On 25 Mar',
#      'money_out': '6.00',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to The Greek Grill HO On 25 Mar',
#      'money_out': '7.00',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Refund From Treatwell On 24 Mar',
#      'money_out': '',
#      'money_in': '15.00',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': '20.00',
#      'balance': '33.44'},
#     {'date': 'Barclays Regulation Registered',
#      'description': 'UK PLC. Authorised by the Prudential Regulation Authority (Financial Services Register No. 759676). in England. Registered No. 9740322. Registered',
#      'money_out': 'and 1 Churchill Place,',
#      'money_in': 'by the Financial London E14 5HP.',
#      'balance': 'Continued Conduct'}]},
#   {'data': [{'date': '28 Mar',
#      'description': 'Card Payment to Caffe Nero Notting On 26 Mar',
#      'money_out': '3.65',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Lidl GB Nottingham On 27 Mar',
#      'money_out': '14.20',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Bill Payment From Thorneloe E J Ref: Food',
#      'money_out': '',
#      'money_in': '3.60',
#      'balance': '19.19'},
#     {'date': '31 Mar',
#      'description': 'Card Payment to Coates On 30 Mar',
#      'money_out': '1.95',
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Refund From Lounge Underwear On 30 Mar',
#      'money_out': '',
#      'money_in': '27.00',
#      'balance': '44.24'},
#     {'date': '31 Mar u the This Page',
#      'description': 'End balance Wrong? If you’ve spotted any next page for how to get in touch interest rates does not pay credit interest Barclays Bank UK PLC. Authorised by 4 Regulation Authority (Financial Registered in England. Registered',
#      'money_out': 'incorrect or us. the Prudential Register No. 9740322.',
#      'money_in': 'unusual Authority Office: 1',
#      'balance': '44.24 see and regulated by Place, London'}]}]}

# %%
cleaned_page
# Out:
# {'forms': [{'sort_code': '20-44-51'},
#   {'account_number': '83254534'},
#   {'customer_name': 'Miss Meghan Victoria Thorneloe'},
#   {'money_in': 66792},
#   {'start_balance': 3630},
#   {'money_out': 65998},
#   {'end_balance': 4424}],
#  'tables': [{'data': [{'date': '2023-03-01',
#      'description': 'Start balance',
#      'money_out': '',
#      'money_in': '',
#      'balance': 3630},
#     {'date': '2023-03-01',
#      'description': 'Transfer to Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': 2400,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Bill Payment From Thorneloe E J Ref: Food',
#      'money_out': '',
#      'money_in': 2400,
#      'balance': 3630},
#     {'date': '2023-03-02',
#      'description': 'Card Payment to Protein Works On 01 Mar',
#      'money_out': 396,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer to Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': 2300,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Received From S Oakley Ref: Water 2',
#      'money_out': '',
#      'money_in': 2333,
#      'balance': 3267},
#     {'date': '2023-03-06',
#      'description': 'Card Payment to Headingley Taps On 04 Mar',
#      'money_out': 60,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Original Oak On 04 Mar',
#      'money_out': 120,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Poco On 04 Mar',
#      'money_out': 250,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Tesco Stores 5628 On 05 Mar',
#      'money_out': 335,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Poco On 04 Mar',
#      'money_out': 800,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to LA Cafetiere On 04 Mar',
#      'money_out': 1000,
#      'money_in': '',
#      'balance': ''},
#     {'date': 'Barclays and the Registered',
#      'description': 'UK PLC. Authorised by the Prudential Regulation Regulation Authority (Financial Services in England.',
#      'money_out': 'and No. 759676). 1 Churchill Place,',
#      'money_in': 14500,
#      'balance': 'Continued Conduct'}]},
#   {'data': [{'date': '2023-03-06',
#      'description': 'Transfer to Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': 2300,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Bill Payment to Jake Holmes Ref: Travel',
#      'money_out': 10000,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Received From Copse S J Ref: Water',
#      'money_out': '',
#      'money_in': 2333,
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': 6000,
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': 10000,
#      'balance': 6735},
#     {'date': '2023-03-07',
#      'description': 'Card Payment to Ltt Vending Limite On 06 Mar',
#      'money_out': 150,
#      'money_in': '',
#      'balance': 6585},
#     {'date': '2023-03-08',
#      'description': 'Card Payment to Avo On 07 Mar',
#      'money_out': 650,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Bill Payment to E J Thorneloe Ref: Food',
#      'money_out': 1600,
#      'money_in': '',
#      'balance': 4335},
#     {'date': '2023-03-09',
#      'description': 'Card Payment to Superpedestrian On 08 Mar',
#      'money_out': 170,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Superpedestrian On 08 Mar',
#      'money_out': 310,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to 200 Degrees On 08 Mar',
#      'money_out': 695,
#      'money_in': '',
#      'balance': 3160},
#     {'date': '2023-03-10',
#      'description': 'Bill Payment to E J Thorneloe Ref: Mothers Day',
#      'money_out': 2400,
#      'money_in': '',
#      'balance': 760},
#     {'date': '2023-03-13',
#      'description': 'Card Payment to London Theatre Dir On 12 Mar',
#      'money_out': 5300,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer to Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': 2300,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer to Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': 2300,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Received From Price M J Ref: Water',
#      'money_out': '',
#      'money_in': 2333,
#      'balance': ''},
#     {'date': '',
#      'description': 'Received From Lamees Ali Ref: Lamees',
#      'money_out': '',
#      'money_in': 2333,
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': 5200,
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': 5300,
#      'balance': 6026},
#     {'date': '2023-03-14',
#      'description': 'Bill Payment to E J Thorneloe Ref: Food',
#      'money_out': 285,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Bill Payment to E J Thorneloe Ref: Food',
#      'money_out': 700,
#      'money_in': '',
#      'balance': 5041},
#     {'date': '2023-03-15',
#      'description': 'Direct Debit to Paypal Payment Ref: 5YV22229Xjkke',
#      'money_out': 794,
#      'money_in': '',
#      'balance': ''},
#     {'date': 'Page',
#      'description': 'Barclays Bank UK PLC. Authorised by 2 Regulation Authority (Financial Registered in England. Registe',
#      'money_out': 'the Prudential Register No. 9740322.',
#      'money_in': 100,
#      'balance': 'Continued and regulated by Place, London'}]},
#   {'data': [{'date': '2023-03-15',
#      'description': 'Direct Debit to Paypal Payment Ref: 5YV22229Xjkke',
#      'money_out': 4446,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': 1000,
#      'balance': 801},
#     {'date': '2023-03-20',
#      'description': 'Card Payment to Avo On 19 Mar',
#      'money_out': 280,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': 6000,
#      'balance': 6521},
#     {'date': '2023-03-21',
#      'description': 'Card Payment to Paypal *BO and Tee On 19 Mar',
#      'money_out': 2500,
#      'money_in': '',
#      'balance': 4021},
#     {'date': '2023-03-22',
#      'description': 'Card Payment to Treatwell On 21 Mar',
#      'money_out': 1500,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Puregym Limited On 21 Mar',
#      'money_out': 1699,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Lounge Underwear On 21 Mar',
#      'money_out': 5850,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Portland Coffee Co On 21 Mar',
#      'money_out': 230,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Bill Payment to E J Thorneloe Ref: Food',
#      'money_out': 250,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': 2000,
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': 2000,
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': 5000,
#      'balance': 3492},
#     {'date': '2023-03-23',
#      'description': 'Card Payment to Trainline.Com On 21 Mar',
#      'money_out': 1399,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': 6000,
#      'balance': 8093},
#     {'date': '2023-03-24',
#      'description': 'Card Payment to SP Aybl On 23 Mar',
#      'money_out': 6624,
#      'money_in': '',
#      'balance': 1469},
#     {'date': '2023-03-27',
#      'description': 'Card Payment to Tesco Stores 5628 On 24 Mar',
#      'money_out': 125,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Sainsburys S/Mkts On 24 Mar',
#      'money_out': 200,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Tier Lounge Nottin On 25 Mar',
#      'money_out': 600,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to The Greek Grill HO On 25 Mar',
#      'money_out': 700,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Refund From Treatwell On 24 Mar',
#      'money_out': '',
#      'money_in': 1500,
#      'balance': ''},
#     {'date': '',
#      'description': 'Transfer From Sort Code 20-44-51 Account 13415759 Ref: Mobile-Channel',
#      'money_out': '',
#      'money_in': 2000,
#      'balance': 3344},
#     {'date': 'Barclays Regulation Registered',
#      'description': 'UK PLC. Authorised by the Prudential Regulation Authority (Financial Services Register No. 759676). ',
#      'money_out': 100,
#      'money_in': 14500,
#      'balance': 'Continued Conduct'}]},
#   {'data': [{'date': '2023-03-28',
#      'description': 'Card Payment to Caffe Nero Notting On 26 Mar',
#      'money_out': 365,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Card Payment to Lidl GB Nottingham On 27 Mar',
#      'money_out': 1420,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Bill Payment From Thorneloe E J Ref: Food',
#      'money_out': '',
#      'money_in': 360,
#      'balance': 1919},
#     {'date': '2023-03-31',
#      'description': 'Card Payment to Coates On 30 Mar',
#      'money_out': 195,
#      'money_in': '',
#      'balance': ''},
#     {'date': '',
#      'description': 'Refund From Lounge Underwear On 30 Mar',
#      'money_out': '',
#      'money_in': 2700,
#      'balance': 4424},
#     {'date': '31 Mar u the This Page',
#      'description': 'End balance Wrong? If you’ve spotted any next page for how to get in touch interest rates does not p',
#      'money_out': 'incorrect or us. the Prudential Register No. 9740322.',
#      'money_in': 100,
#      'balance': 4424}]}]}
